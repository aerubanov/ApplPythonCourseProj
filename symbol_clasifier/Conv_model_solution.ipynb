# %%
import pickle
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from keras.models import Sequential,Model
from keras.layers import Dense, Input, Flatten, Conv2D, MaxPooling2D
# Out:
# Using TensorFlow backend.

# %%
x_train = pd.read_pickle("/home/francuz-v/CROHME_extractor/outputs/x_train.pickle")
y_train = pd.read_pickle("/home/francuz-v/CROHME_extractor/outputs/y_train.pickle")

# %%
classes_num = y_train.shape[1]

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=6, activation='relu', input_shape=(34, 34, 1)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(32, kernel_size=3, activation='relu'))
model.add(Flatten())
model.add(Dense(classes_num, activation='softmax'))

# %%
x_test = pd.read_pickle("/home/francuz-v/CROHME_extractor/outputs/x_test.pickle")
y_test = pd.read_pickle("/home/francuz-v/CROHME_extractor/outputs/y_test.pickle")

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, batch_size=256, epochs=5, validation_data=(x_test, y_test))
# Out:
# Train on 150000 samples, validate on 11576 samples
# Epoch 1/5
# 150000/150000 [==============================] - 230s 2ms/step - loss: 0.9004 - accuracy: 0.7497 - val_loss: 0.6128 - val_accuracy: 0.8251
# Epoch 2/5
# 150000/150000 [==============================] - 247s 2ms/step - loss: 0.4152 - accuracy: 0.8694 - val_loss: 0.5564 - val_accuracy: 0.8476
# Epoch 3/5
# 150000/150000 [==============================] - 240s 2ms/step - loss: 0.2960 - accuracy: 0.9054 - val_loss: 0.5546 - val_accuracy: 0.8526
# Epoch 4/5
# 150000/150000 [==============================] - 247s 2ms/step - loss: 0.2285 - accuracy: 0.9261 - val_loss: 0.5900 - val_accuracy: 0.8436
# Epoch 5/5
# 150000/150000 [==============================] - 240s 2ms/step - loss: 0.1890 - accuracy: 0.9376 - val_loss: 0.5940 - val_accuracy: 0.8503

# %%
with open('model_34_filt6.obj', 'wb') as f:
    pickle.dump(model, f)

# %%
with open('model34.obj', 'rb') as f:
    model1 = pickle.load(f)
with open('model_34_filt5.obj', 'rb') as f:
    model2 = pickle.load(f)
with open('model_34_filt6.obj', 'rb') as f:
    model3 = pickle.load(f)

# %%
y_1 = model1.predict(x_test)
y_2 = model2.predict(x_test)
y_3 = model3.predict(x_test)

# %%
print(y_1[:20])
print(y_2[:20])
print(y_3[:20])
# Out:
# [[1.98014243e-20 9.26863231e-06 1.15079096e-17 ... 7.63778075e-07
#   1.20630773e-07 1.32125313e-15]
#  [1.01512836e-16 1.03323140e-11 3.00308570e-16 ... 6.18313106e-06
#   6.09390668e-07 2.98851647e-15]
#  [1.09030399e-15 4.79382743e-16 1.79951414e-08 ... 5.09187554e-14
#   1.17211471e-12 2.55223249e-18]
#  ...
#  [1.26632515e-20 2.00260364e-11 2.86677758e-21 ... 3.59292457e-11
#   1.20372309e-10 6.92409597e-17]
#  [3.57109294e-14 1.27142556e-12 9.17565942e-01 ... 5.17386470e-05
#   2.00001598e-08 1.28462086e-15]
#  [5.75508263e-09 2.23296136e-03 2.37453625e-14 ... 2.38393955e-06
#   1.95948724e-06 1.08750634e-15]]
# [[9.4681508e-24 4.6077790e-08 6.0636526e-16 ... 2.6169803e-07
#   1.7342069e-08 1.0499594e-12]
#  [8.3579760e-10 4.8360751e-09 1.9629728e-12 ... 2.8128832e-06
#   3.1115712e-06 4.0824695e-13]
#  [1.2042895e-15 1.2215749e-16 4.5210142e-09 ... 8.2511020e-16
#   1.4587157e-13 2.4077003e-17]
#  ...
#  [1.3676078e-14 1.7641391e-08 8.0495632e-17 ... 7.5253592e-10
#   2.3377376e-08 5.9500122e-12]
#  [1.2742865e-08 5.1321799e-13 4.7215369e-01 ... 1.2133190e-05
#   2.2928869e-08 6.4382544e-12]
#  [6.1821630e-08 5.1960786e-04 2.4653437e-13 ... 9.0139892e-08
#   3.6071899e-06 1.4259059e-14]]
# [[4.1609162e-19 2.3583043e-05 5.2235497e-15 ... 2.2779549e-08
#   1.0562722e-09 2.6621655e-10]
#  [5.0488108e-10 4.7475034e-08 5.5769439e-12 ... 3.8406329e-06
#   5.4114565e-08 2.2273274e-11]
#  [1.0587575e-16 1.1559902e-14 4.4671951e-09 ... 3.7207345e-15
#   7.1690280e-16 2.5425778e-18]
#  ...
#  [1.9883104e-18 2.8566979e-10 3.9779806e-18 ... 9.8965313e-13
#   2.1321323e-11 2.4686812e-13]
#  [1.6333229e-09 2.1305593e-13 6.7810255e-01 ... 4.2308253e-05
#   1.9783586e-08 3.2053624e-11]
#  [1.9806614e-09 2.4117115e-03 1.4823325e-13 ... 3.6061412e-08
#   3.2249371e-08 2.0328579e-14]]

# %%
from model_assembly import Model_Assembly

# %%
model_a = Model_Assembly()

# %%
prediction = model_a.predict(x_test)

# %%
prediction[0:20]
# Out:
# array([54, 93, 63,  8,  5, 41,  1,  5, 97, 10,  5, 93,  2,  5, 10, 93, 98,
#        96,  2, 14])

# %%
result1 = []
for i in range(x_test.shape[0]):
    result.append(np.argmax(y_1[i]))

# %%
result1[:20]
# Out:
# [54, 93, 63, 8, 5, 41, 1, 5, 97, 10, 5, 3, 2, 5, 10, 93, 98, 96, 2, 14]

# %%
result = []
for i in range(x_test.shape[0]):
    result.append(np.argmax(y_2[i]))

# %%
result[:20]
# Out:
# [54, 93, 63, 88, 5, 41, 1, 5, 97, 10, 5, 93, 2, 5, 10, 93, 36, 96, 4, 14]

# %%
result = []
for i in range(x_test.shape[0]):
    result.append(np.argmax(y_3[i]))
result[:20]
# Out:
# [54, 93, 63, 8, 5, 41, 1, 5, 97, 10, 5, 93, 2, 5, 10, 93, 98, 96, 2, 14]

# %%
true_y = []
for i in range(x_test.shape[0]):
    true_y.append(list(y_test.iloc[i]).index(1))
true_y
# Out:
# [54,
#  93,
#  63,
#  8,
#  5,
#  41,
#  1,
#  5,
#  97,
#  10,
#  5,
#  93,
#  2,
#  5,
#  10,
#  93,
#  36,
#  87,
#  2,
#  1,
#  67,
#  87,
#  84,
#  18,
#  9,
#  84,
#  18,
#  5,
#  9,
#  10,
#  1,
#  87,
#  10,
#  3,
#  87,
#  2,
#  40,
#  3,
#  39,
#  1,
#  74,
#  10,
#  3,
#  75,
#  10,
#  2,
#  1,
#  76,
#  10,
#  3,
#  77,
#  10,
#  2,
#  46,
#  1,
#  74,
#  76,
#  3,
#  75,
#  77,
#  2,
#  10,
#  9,
#  5,
#  74,
#  8,
#  5,
#  75,
#  97,
#  1,
#  39,
#  9,
#  4,
#  39,
#  87,
#  2,
#  52,
#  4,
#  79,
#  1,
#  2,
#  74,
#  87,
#  99,
#  87,
#  18,
#  99,
#  67,
#  78,
#  69,
#  10,
#  82,
#  37,
#  5,
#  10,
#  11,
#  1,
#  9,
#  3,
#  5,
#  17,
#  12,
#  97,
#  2,
#  5,
#  11,
#  10,
#  5,
#  12,
#  17,
#  73,
#  12,
#  8,
#  1,
#  97,
#  4,
#  98,
#  2,
#  4,
#  2,
#  1,
#  18,
#  9,
#  9,
#  79,
#  1,
#  2,
#  87,
#  97,
#  18,
#  97,
#  1,
#  99,
#  5,
#  87,
#  10,
#  3,
#  98,
#  5,
#  87,
#  10,
#  2,
#  1,
#  99,
#  5,
#  87,
#  10,
#  5,
#  98,
#  5,
#  87,
#  10,
#  2,
#  18,
#  97,
#  5,
#  9,
#  74,
#  23,
#  1,
#  74,
#  97,
#  3,
#  75,
#  2,
#  3,
#  21,
#  54,
#  99,
#  63,
#  8,
#  5,
#  9,
#  55,
#  74,
#  1,
#  9,
#  3,
#  99,
#  2,
#  5,
#  9,
#  99,
#  54,
#  97,
#  63,
#  8,
#  1,
#  9,
#  3,
#  97,
#  2,
#  5,
#  9,
#  97,
#  54,
#  93,
#  63,
#  8,
#  5,
#  41,
#  1,
#  5,
#  97,
#  10,
#  5,
#  93,
#  2,
#  5,
#  10,
#  93,
#  79,
#  1,
#  87,
#  70,
#  86,
#  2,
#  79,
#  1,
#  87,
#  2,
#  70,
#  79,
#  1,
#  86,
#  8,
#  2,
#  18,
#  18,
#  5,
#  9,
#  74,
#  23,
#  1,
#  74,
#  97,
#  3,
#  75,
#  2,
#  3,
#  21,
#  79,
#  1,
#  97,
#  2,
#  9,
#  5,
#  75,
#  5,
#  74,
#  18,
#  54,
#  93,
#  63,
#  49,
#  1,
#  9,
#  3,
#  5,
#  9,
#  93,
#  2,
#  93,
#  18,
#  78,
#  54,
#  97,
#  63,
#  8,
#  5,
#  1,
#  9,
#  5,
#  41,
#  97,
#  2,
#  1,
#  9,
#  3,
#  41,
#  97,
#  2,
#  97,
#  10,
#  1,
#  9,
#  3,
#  41,
#  97,
#  2,
#  67,
#  9,
#  87,
#  98,
#  10,
#  9,
#  82,
#  18,
#  82,
#  18,
#  1,
#  99,
#  5,
#  87,
#  10,
#  3,
#  98,
#  5,
#  87,
#  10,
#  2,
#  1,
#  99,
#  5,
#  87,
#  10,
#  5,
#  98,
#  5,
#  87,
#  10,
#  2,
#  18,
#  97,
#  65,
#  97,
#  5,
#  65,
#  98,
#  5,
#  65,
#  1,
#  97,
#  5,
#  98,
#  2,
#  79,
#  5,
#  87,
#  2,
#  9,
#  1,
#  78,
#  93,
#  2,
#  1,
#  1,
#  97,
#  11,
#  5,
#  97,
#  10,
#  5,
#  97,
#  2,
#  1,
#  10,
#  97,
#  5,
#  15,
#  2,
#  84,
#  5,
#  9,
#  8,
#  97,
#  18,
#  50,
#  5,
#  60,
#  10,
#  8,
#  71,
#  1,
#  41,
#  97,
#  3,
#  78,
#  97,
#  2,
#  5,
#  1,
#  78,
#  97,
#  5,
#  41,
#  97,
#  2,
#  72,
#  77,
#  97,
#  13,
#  14,
#  5,
#  1,
#  9,
#  12,
#  8,
#  7,
#  17,
#  8,
#  7,
#  1,
#  9,
#  10,
#  2,
#  2,
#  70,
#  1,
#  9,
#  14,
#  15,
#  5,
#  9,
#  12,
#  15,
#  2,
#  11,
#  16,
#  13,
#  15,
#  15,
#  16,
#  12,
#  18,
#  6,
#  89,
#  1,
#  2,
#  87,
#  5,
#  67,
#  87,
#  84,
#  9,
#  74,
#  87,
#  5,
#  84,
#  35,
#  87,
#  5,
#  84,
#  35,
#  18,
#  35,
#  18,
#  65,
#  1,
#  39,
#  3,
#  40,
#  2,
#  65,
#  1,
#  39,
#  5,
#  40,
#  2,
#  18,
#  65,
#  10,
#  39,
#  5,
#  65,
#  10,
#  40,
#  11,
#  98,
#  10,
#  3,
#  11,
#  98,
#  3,
#  9,
#  66,
#  10,
#  1,
#  5,
#  9,
#  66,
#  10,
#  65,
#  97,
#  3,
#  5,
#  9,
#  66,
#  10,
#  41,
#  97,
#  2,
#  1,
#  99,
#  5,
#  87,
#  10,
#  3,
#  98,
#  5,
#  87,
#  10,
#  2,
#  1,
#  99,
#  5,
#  87,
#  10,
#  5,
#  98,
#  5,
#  87,
#  10,
#  2,
#  18,
#  97,
#  9,
#  15,
#  11,
#  70,
#  1,
#  1,
#  9,
#  16,
#  8,
#  70,
#  9,
#  15,
#  15,
#  2,
#  7,
#  1,
#  11,
#  12,
#  3,
#  13,
#  12,
#  2,
#  2,
#  9,
#  16,
#  9,
#  58,
#  50,
#  10,
#  9,
#  1,
#  5,
#  97,
#  10,
#  5,
#  9,
#  97,
#  10,
#  2,
#  78,
#  97,
#  3,
#  5,
#  9,
#  97,
#  77,
#  97,
#  9,
#  8,
#  10,
#  5,
#  9,
#  54,
#  97,
#  63,
#  8,
#  5,
#  1,
#  9,
#  5,
#  41,
#  97,
#  2,
#  1,
#  9,
#  3,
#  41,
#  97,
#  2,
#  97,
#  10,
#  1,
#  9,
#  3,
#  41,
#  97,
#  2,
#  54,
#  93,
#  63,
#  8,
#  5,
#  41,
#  1,
#  5,
#  97,
#  10,
#  5,
#  93,
#  2,
#  5,
#  10,
#  93,
#  16,
#  8,
#  3,
#  1,
#  9,
#  9,
#  12,
#  7,
#  9,
#  15,
#  10,
#  2,
#  5,
#  9,
#  8,
#  58,
#  1,
#  97,
#  11,
#  5,
#  97,
#  10,
#  5,
#  97,
#  2,
#  1,
#  10,
#  97,
#  5,
#  15,
#  2,
#  50,
#  1,
#  10,
#  97,
#  5,
#  11,
#  78,
#  97,
#  2,
#  77,
#  97,
#  13,
#  4,
#  70,
#  5,
#  16,
#  8,
#  9,
#  8,
#  9,
#  14,
#  8,
#  50,
#  5,
#  60,
#  10,
#  8,
#  71,
#  1,
#  41,
#  97,
#  3,
#  78,
#  97,
#  2,
#  5,
#  1,
#  78,
#  97,
#  5,
#  41,
#  97,
#  2,
#  72,
#  77,
#  97,
#  50,
#  5,
#  60,
#  10,
#  8,
#  71,
#  1,
#  41,
#  97,
#  3,
#  78,
#  97,
#  2,
#  5,
#  1,
#  78,
#  97,
#  5,
#  41,
#  97,
#  2,
#  72,
#  77,
#  97,
#  9,
#  14,
#  17,
#  10,
#  3,
#  13,
#  5,
#  14,
#  14,
#  61,
#  13,
#  78,
#  10,
#  9,
#  3,
#  78,
#  11,
#  10,
#  3,
#  78,
#  12,
#  11,
#  3,
#  78,
#  13,
#  12,
#  54,
#  93,
#  63,
#  49,
#  1,
#  9,
#  3,
#  5,
#  9,
#  93,
#  2,
#  93,
#  18,
#  78,
#  1,
#  97,
#  11,
#  5,
#  97,
#  10,
#  5,
#  97,
#  2,
#  1,
#  10,
#  97,
#  5,
#  15,
#  2,
#  9,
#  14,
#  14,
#  70,
#  1,
#  1,
#  15,
#  9,
#  9,
#  15,
#  13,
#  2,
#  5,
#  16,
#  11,
#  2,
#  5,
#  9,
#  11,
#  15,
#  9,
#  8,
#  14,
#  42,
#  18,
#  6,
#  13,
#  78,
#  9,
#  17,
#  18,
#  9,
#  82,
#  18,
#  54,
#  93,
#  63,
#  8,
#  5,
#  41,
#  1,
#  5,
#  97,
#  10,
#  5,
#  93,
#  2,
#  5,
#  10,
#  93,
#  9,
#  87,
#  53,
#  82,
#  53,
#  5,
#  98,
#  9,
#  98,
#  10,
#  98,
#  11,
#  98,
#  12,
#  1,
#  3,
#  2,
#  1,
#  3,
#  2,
#  9,
#  17,
#  15,
#  3,
#  14,
#  10,
#  5,
#  15,
#  12,
#  58,
#  19,
#  9,
#  4,
#  19,
#  10,
#  4,
#  4,
#  19,
#  87,
#  52,
#  50,
#  5,
#  60,
#  10,
#  8,
#  71,
#  1,
#  41,
#  97,
#  3,
#  78,
#  97,
#  2,
#  5,
#  1,
#  78,
#  97,
#  5,
#  41,
#  97,
#  2,
#  72,
#  77,
#  97,
#  1,
#  9,
#  4,
#  4,
#  87,
#  2,
#  97,
#  52,
#  97,
#  19,
#  70,
#  1,
#  20,
#  21,
#  2,
#  1,
#  19,
#  70,
#  20,
#  2,
#  21,
#  70,
#  18,
#  70,
#  50,
#  10,
#  9,
#  1,
#  5,
#  97,
#  10,
#  5,
#  9,
#  97,
#  10,
#  2,
#  78,
#  97,
#  3,
#  5,
#  9,
#  97,
#  77,
#  97,
#  97,
#  2,
#  1,
#  82,
#  1,
#  11,
#  9,
#  7,
#  9,
#  16,
#  3,
#  9,
#  10,
#  1,
#  2,
#  2,
#  3,
#  11,
#  14,
#  11,
#  15,
#  8,
#  11,
#  18,
#  6,
#  1,
#  99,
#  5,
#  87,
#  10,
#  3,
#  98,
#  5,
#  87,
#  10,
#  2,
#  1,
#  99,
#  5,
#  87,
#  10,
#  5,
#  98,
#  5,
#  87,
#  10,
#  2,
#  18,
#  97,
#  37,
#  5,
#  10,
#  11,
#  1,
#  9,
#  3,
#  5,
#  17,
#  12,
#  97,
#  2,
#  5,
#  11,
#  10,
#  5,
#  12,
#  17,
#  73,
#  12,
#  8,
#  1,
#  9,
#  3,
#  2,
#  82,
#  35,
#  1,
#  ...]

# %%
symbol_dict = {}
with open('../classes.txt', 'r') as f:
    i = 0
    for line in f:
        symbol_dict[i] = line.strip()
        i += 1

# %%
symbol_dict

# %%
for i in range(df.shape[0]):
    df['label'][i] = list(test_data[i]['label']).index(1)

# %%
df.head()

# %%
class_s = df[df['label'] == 62]

# %%
class_s.shape

# %%
plt.figure(figsize=(10,10))
j = 0
for i in class_s.index:
    plt.subplot(10,5,j+1)
    j += 1
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(class_s['features'][i].reshape((28,28)), cmap=plt.cm.binary)
    #plt.xlabel(class_s[i]['label']) # number of class

# %%
model.save('symbol_classifier_conv.h5')

# %%
model_saved = keras.models.load_model('symbol_classifier.h5')

# %%
model_saved.summary()

# %%
loss, acc = model_saved.evaluate(x_train[:1000], y_train[:1000])

# %%
loss, acc = model_saved.evaluate(x_test[2849:], y_test[2849:])
